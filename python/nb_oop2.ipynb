# %% [markdown]
# ## Bibliotecas utilizadas

# %%
import pandas as pd
from opencage.geocoder import OpenCageGeocode
import json
from concurrent.futures import ThreadPoolExecutor
from tqdm import tqdm
from pprint import pprint
from ipyleaflet import *
from ipyleaflet import Map, Marker

# %% [markdown]
# ## Classe e métodos

# %%
class Preparador:
    
    # Classe responsável pelo carregamento inicial do dataframe
    def __init__(self, dataset):
        self.df = pd.read_csv(dataset, sep='\n', delimiter=';')
        self.fields = list(self.df)
        self.n_lines = len(self.df)

        
    def get_df(self):
        return self.df
    
    # Para cada coluna identique a quantidade de linhas com dados faltantes (em alguns casos,
    # o dado faltante é uma string vazia, em outros casos é uma string contendo algum valor do tipo:
    # "sem informação"). Faça um método que retorna a média de dados faltantes por coluna
    def search_nan(self):
        count = {}
        for field in self.fields:
            count[field] = 100*sum(
                [1 if value == "" or value == "Sem Informações" else 0 for value in self.df[field]]) / self.n_lines
        return count

    # Para cada item identifique até qual nível taxônomico a ocorrência foi identificada.
    def n_tax(self):
        count = {}
        for i in range(self.n_lines):
            count[i] = ""
            for field in reversed(['Reino', 'Filo', 'Classe', 'Ordem', 'Familia', 'Genero', 'Especie']):
                if self.df.loc[i,field] != "Sem Informações" and self.df.loc[i,field] != "":
                    count[i] = field
                    break
        return count

    # Monte filtros de ocorrências por estados, nome de espécie (nome exato ou parte do nome)
    #  e categoria de ameaça, e outros filtros que julgar relevante.
    def filter(self):
        print('Filtrar dados por:')
        print('1. Estado')
        print('2. Nome de espécie')
        print('3. Categoria de ameaça')
        n = int(input('Digite o número da opção: '))
        if n==1:
            est = str(input('Digite a sigla do estado: '))
            new_df = self.df[self.df['Estado/Provincia'] == est]
            
        elif n==2:
            esp = str(input('Digite o nome da espécie: '))
            new_df = self.df[self.df['Especie'] == esp]        
            
        elif n==3:
            ameaca = str(input('Digite a categoria de ameaça: '))
            new_df = self.df[self.df['Categoria de Ameaca'] == ameaca]
        print("Ocorrências com o filtro aplicado:", len(new_df))
        pprint(new_df)
        return new_df

    # Crie uma funcionalidade para avaliar se a informação de longitude e latitude corresponde
    #  a informação presente na localização
    def verify_lat_long(self, city, lat, long):
        key = '65b25c705a5349ad99c824ca809363b7'
        geocoder = OpenCageGeocode(key)
        results = geocoder.reverse_geocode(lat, long)
        pprint(results)
        try:
            r_city = results[0]['components']['city']
        except Exception as identifier:
            try:
                r_city = results[0]['components']['island']
            except Exception as identifier:
                r_city = ""
        self.pbar.update(1)
        return r_city == city

    # Plota coordenadas especificas no mapa
    # Aqui é possível verificar visualmente o local de ocorrência de diferentes espécies
    def plot_map(self, newdf):
        my_center = geocoder.geocode(u'Salvador, Brazil')
        center = (my_center[0]['geometry']['lat'], my_center[0]['geometry']['lng'])
        map = Map(center=center, zoom=5)
        # loc1 =(self.df["Latitude"][0], self.df["Longitude"][0])
        # loc2 = (self.df["Latitude"][250], self.df["Longitude"][250])
        # marker1 = Marker(location=loc1, draggable=True)
        # marker2 = Marker(location=loc2, draggable=True)
        # map.add_layer(marker1)
        # map.add_layer(marker2)
        for i in newdf.index:
            loc =(newdf["Latitude"][i], newdf["Longitude"][i])
            marker = Marker(location=loc)
            map.add_layer(marker)
        mymap = map
        return(mymap)
        
        
    def call(self):
        futures = {}
        count = {}
        self.pbar = tqdm(total=len(self.df))
        with ThreadPoolExecutor(max_workers=100) as executor:
            for i, (lat, long, city) in enumerate(zip(self.df['Latitude'], self.df['Longitude'], self.df['Municipio'])):
                futures[i] = executor.submit(self.verify_lat_long, city, lat, long)

        for i, f in futures.items():
            count[i] = f.result()
        return countpreparador.plot_map()

# %% [markdown]
# ## Criação da instância da classe e utilização dos métodos

# %%
# Inserção da key do geocoder
key = 'fc805050230944ecabeae3cc1eeefc6e'
geocoder = OpenCageGeocode(key)

# Cria a instância da classe
# arquivo = 'portalbio_export_17-10-2019-13-06-22.csv'
arquivo = 'portalbio_export_16-10-2019-14-39-54.csv'
preparador = Preparador(arquivo)

# Retorna o dataframe para checagem
mydf = preparador.get_df()
pprint(mydf)

# Printa a quantidade de linhas55
# A quantidade de linhas indica a quantidade de espécies registradas neste documento
print("Quantidade de espécies registradas: ", len(mydf))
# Out:
#      Nome da instituicao Sigla da instituicao  \
# 0        Sem Informações               ICMBio
# 1        Sem Informações               ICMBio
# 2        Sem Informações               ICMBio
# 3        Sem Informações               ICMBio
# 4        Sem Informações               ICMBio
# ...                  ...                  ...
# 3907     Sem Informações               ICMBio
# 3908     Sem Informações               ICMBio
# 3909     Sem Informações               ICMBio
# 3910     Sem Informações               ICMBio
# 3911     Sem Informações               ICMBio
#
#                                   Nome da base de dados  \
# 0                 Atlas de Registro de Aves Brasileiras
# 1                 Atlas de Registro de Aves Brasileiras
# 2                 Atlas de Registro de Aves Brasileiras
# 3                 Atlas de Registro de Aves Brasileiras
# 4                 Atlas de Registro de Aves Brasileiras
# ...                                                 ...
# 3907  Sistema de Autorização e Informação em Biodive...
# 3908  Sistema de Autorização e Informação em Biodive...
# 3909  Sistema de Autorização e Informação em Biodive...
# 3910  Sistema de Autorização e Informação em Biodive...
# 3911  Sistema de Autorização e Informação em Biodive...
#
#                             Sigla da base de dados  \
# 0     ARA - Atlas de Registros de Aves Brasileiras
# 1     ARA - Atlas de Registros de Aves Brasileiras
# 2     ARA - Atlas de Registros de Aves Brasileiras
# 3     ARA - Atlas de Registros de Aves Brasileiras
# 4     ARA - Atlas de Registros de Aves Brasileiras
# ...                                            ...
# 3907                                  SISBIO-DIBIO
# 3908                                  SISBIO-DIBIO
# 3909                                  SISBIO-DIBIO
# 3910                                  SISBIO-DIBIO
# 3911                                  SISBIO-DIBIO
#
#                               Responsavel pelo registro  \
# 0     Ibama (Instituto Brasileiro de Meio Ambiente e...
# 1     Ibama (Instituto Brasileiro de Meio Ambiente e...
# 2     Ibama (Instituto Brasileiro de Meio Ambiente e...
# 3     Ibama (Instituto Brasileiro de Meio Ambiente e...
# 4     Ibama (Instituto Brasileiro de Meio Ambiente e...
# ...                                                 ...
# 3907                       Luiz Ricardo Lopes De Simone
# 3908                       Luiz Ricardo Lopes De Simone
# 3909                       Luiz Ricardo Lopes De Simone
# 3910                                        Maíra Pombo
# 3911                                        Maíra Pombo
#
#      Numero do registro no portal  \
# 0                   ARA-LIT-95641
# 1                   ARA-LIT-95642
# 2                   ARA-LIT-95643
# 3                   ARA-LIT-95644
# 4                   ARA-LIT-95645
# ...                           ...
# 3907                        99355
# 3908                        99360
# 3909                        99362
# 3910                       975640
# 3911                       975642
#
#                     Numero do registro na base de dados Data do registro  \
# 0                                       Sem Informações  Sem Informações
# 1                                       Sem Informações  Sem Informações
# 2                                       Sem Informações  Sem Informações
# 3                                       Sem Informações  Sem Informações
# 4                                       Sem Informações  Sem Informações
# ...                                                 ...              ...
# 3907  Nº Da Autorização/Licença Sisbio: 26780, Proje...       14/01/2012
# 3908  Nº Da Autorização/Licença Sisbio: 26780, Proje...       14/01/2012
# 3909  Nº Da Autorização/Licença Sisbio: 26780, Proje...       14/01/2012
# 3910  Nº Da Autorização/Licença Sisbio: 50823, Proje...       31/03/2016
# 3911  Nº Da Autorização/Licença Sisbio: 50823, Proje...       31/03/2016
#
#                Data do evento Data de Carencia  ...  \
# 0             Sem Informações       27/09/2017  ...
# 1             Sem Informações       27/09/2017  ...
# 2             Sem Informações       27/09/2017  ...
# 3             Sem Informações       27/09/2017  ...
# 4             Sem Informações       27/09/2017  ...
# ...                       ...              ...  ...
# 3907  15/01/2012 a 29/02/2012       03/06/2014  ...
# 3908  15/01/2012 a 29/02/2012       03/06/2014  ...
# 3909  15/01/2012 a 29/02/2012       03/06/2014  ...
# 3910  01/04/2016 a 05/04/2016       02/11/2017  ...
# 3911  01/04/2016 a 05/04/2016       02/11/2017  ...
#
#                                           Localidade             Pais  \
# 0                         APA de Fernando de Noronha  Sem Informações
# 1                         APA de Fernando de Noronha  Sem Informações
# 2                         APA de Fernando de Noronha  Sem Informações
# 3                         APA de Fernando de Noronha  Sem Informações
# 4                         APA de Fernando de Noronha  Sem Informações
# ...                                              ...              ...
# 3907                   Ilha Da Trindade E Martin Vaz           Brasil
# 3908                   Ilha Da Trindade E Martin Vaz           Brasil
# 3909                   Ilha Da Trindade E Martin Vaz           Brasil
# 3910  Parque Nacional Marinho De Fernando De Noronha           Brasil
# 3911  Parque Nacional Marinho De Fernando De Noronha           Brasil
#
#      Estado/Provincia            Municipio Status de Sensibilidade   Latitude  \
# 0                  PE  Fernando de Noronha    Espécie não Sensível  -3.849000
# 1                  PE  Fernando de Noronha    Espécie não Sensível  -3.849000
# 2                  PE  Fernando de Noronha    Espécie não Sensível  -3.849000
# 3                  PE  Fernando de Noronha    Espécie não Sensível  -3.849000
# 4                  PE  Fernando de Noronha    Espécie não Sensível  -3.849000
# ...               ...                  ...                     ...        ...
# 3907               ES              Vitoria    Espécie não Sensível -20.504167
# 3908               ES              Vitoria    Espécie não Sensível -20.504167
# 3909               ES              Vitoria    Espécie não Sensível -20.504167
# 3910               PE      Sem Informações    Espécie não Sensível  -3.865667
# 3911               PE      Sem Informações    Espécie não Sensível  -3.844944
#
#       Longitude Outras informacoes da localidade       Jurisdicao  \
# 0    -32.420000   Coordenada exata da ocorr?ncia  Sem Informações
# 1    -32.420000   Coordenada exata da ocorr?ncia  Sem Informações
# 2    -32.420000   Coordenada exata da ocorr?ncia  Sem Informações
# 3    -32.420000   Coordenada exata da ocorr?ncia  Sem Informações
# 4    -32.420000   Coordenada exata da ocorr?ncia  Sem Informações
# ...         ...                              ...              ...
# 3907 -29.306106                  Sem Informações  Sem Informações
# 3908 -29.306106                  Sem Informações  Sem Informações
# 3909 -29.306106                  Sem Informações  Sem Informações
# 3910 -32.422917            Coordenada aproximada  Sem Informações
# 3911 -32.428167            Coordenada aproximada  Sem Informações
#
#           Destino do Material
# 0             Sem Informações
# 1             Sem Informações
# 2             Sem Informações
# 3             Sem Informações
# 4             Sem Informações
# ...                       ...
# 3907       Destinado (outros)
# 3908       Destinado (outros)
# 3909       Destinado (outros)
# 3910  Destinado a laboratório
# 3911  Destinado a laboratório
#
# [3912 rows x 34 columns]
# Quantidade de espécies registradas:  3912

# %% [markdown]
# ## Verificação dos dados faltantes no arquivo CSV

# %%
print("Dicionário com as informações sobre dados faltantes.")
print("No formato {campo: porcentagem de células sem dados}")
preparador.search_nan()
# Out:
# Dicionário com as informações sobre dados faltantes.
# No formato {campo: porcentagem de células sem dados}
# {'Nome da instituicao': 100.0,
#  'Sigla da instituicao': 0.0,
#  'Nome da base de dados': 0.0,
#  'Sigla da base de dados': 0.0,
#  'Responsavel pelo registro': 0.07668711656441718,
#  'Numero do registro no portal': 0.0,
#  'Numero do registro na base de dados': 6.007157464212679,
#  'Data do registro': 3.502044989775051,
#  'Data do evento': 54.4478527607362,
#  'Data de Carencia': 0.0,
#  'Nome cientifico': 1.687116564417178,
#  'Nome comum': 74.20756646216769,
#  'Nome cientifico na base de dados': 0.0,
#  'Nivel taxonomico': 1.687116564417178,
#  'Numero de individuos': 51.35480572597137,
#  'Reino': 100.0,
#  'Filo': 3.1697341513292434,
#  'Classe': 3.7576687116564416,
#  'Ordem': 4.294478527607362,
#  'Familia': 4.729038854805726,
#  'Genero': 16.51329243353783,
#  'Especie': 37.44887525562372,
#  'Estado de conservacao': 0.0,
#  'Categoria de Ameaca': 85.12269938650307,
#  'Localidade': 1.9427402862985685,
#  'Pais': 3.425357873210634,
#  'Estado/Provincia': 10.557259713701432,
#  'Municipio': 42.12678936605317,
#  'Status de Sensibilidade': 0.0,
#  'Latitude': 0.0,
#  'Longitude': 0.0,
#  'Outras informacoes da localidade': 55.802658486707564,
#  'Jurisdicao': 100.0,
#  'Destino do Material': 55.010224948875255}

# %% [markdown]
# ## Verificação do nível taxonômico de cada espécie registrada

# %%
print("Dicionário com as informações sobre dados faltantes.")
print("No formato {número da espécie: nível taxonômico}")
preparador.n_tax()
# Out:
# Dicionário com as informações sobre dados faltantes.
# No formato {número da espécie: nível taxonômico}
# {0: 'Especie',
#  1: 'Especie',
#  2: 'Especie',
#  3: 'Especie',
#  4: 'Especie',
#  5: 'Especie',
#  6: 'Especie',
#  7: 'Especie',
#  8: 'Especie',
#  9: 'Especie',
#  10: 'Especie',
#  11: 'Especie',
#  12: 'Especie',
#  13: 'Especie',
#  14: 'Especie',
#  15: 'Especie',
#  16: 'Especie',
#  17: 'Especie',
#  18: 'Especie',
#  19: 'Especie',
#  20: 'Especie',
#  21: 'Especie',
#  22: 'Especie',
#  23: '',
#  24: '',
#  25: '',
#  26: '',
#  27: 'Especie',
#  28: 'Especie',
#  29: 'Especie',
#  30: 'Especie',
#  31: 'Especie',
#  32: 'Especie',
#  33: 'Especie',
#  34: 'Genero',
#  35: 'Especie',
#  36: 'Genero',
#  37: 'Genero',
#  38: 'Genero',
#  39: 'Genero',
#  40: 'Genero',
#  41: 'Genero',
#  42: 'Genero',
#  43: 'Especie',
#  44: 'Genero',
#  45: 'Familia',
#  46: 'Especie',
#  47: 'Familia',
#  48: 'Genero',
#  49: 'Genero',
#  50: 'Genero',
#  51: 'Especie',
#  52: 'Especie',
#  53: 'Especie',
#  54: 'Genero',
#  55: 'Especie',
#  56: 'Especie',
#  57: 'Genero',
#  58: 'Genero',
#  59: 'Familia',
#  60: 'Especie',
#  61: 'Genero',
#  62: '',
#  63: 'Genero',
#  64: 'Genero',
#  65: 'Especie',
#  66: 'Especie',
#  67: 'Genero',
#  68: 'Genero',
#  69: 'Genero',
#  70: 'Genero',
#  71: 'Especie',
#  72: 'Genero',
#  73: 'Especie',
#  74: 'Especie',
#  75: 'Especie',
#  76: 'Genero',
#  77: 'Especie',
#  78: 'Especie',
#  79: 'Genero',
#  80: 'Genero',
#  81: 'Genero',
#  82: 'Especie',
#  83: 'Genero',
#  84: 'Genero',
#  85: 'Genero',
#  86: 'Especie',
#  87: 'Genero',
#  88: 'Genero',
#  89: 'Genero',
#  90: 'Especie',
#  91: 'Especie',
#  92: 'Genero',
#  93: 'Especie',
#  94: 'Especie',
#  95: 'Genero',
#  96: 'Familia',
#  97: 'Genero',
#  98: 'Especie',
#  99: 'Familia',
#  100: 'Especie',
#  101: 'Especie',
#  102: 'Especie',
#  103: 'Especie',
#  104: 'Genero',
#  105: 'Especie',
#  106: 'Especie',
#  107: 'Especie',
#  108: 'Especie',
#  109: 'Familia',
#  110: 'Familia',
#  111: 'Especie',
#  112: 'Genero',
#  113: 'Genero',
#  114: '',
#  115: 'Especie',
#  116: 'Genero',
#  117: 'Especie',
#  118: 'Especie',
#  119: 'Especie',
#  120: 'Genero',
#  121: 'Genero',
#  122: 'Especie',
#  123: 'Especie',
#  124: 'Especie',
#  125: 'Especie',
#  126: 'Especie',
#  127: 'Genero',
#  128: 'Especie',
#  129: 'Especie',
#  130: 'Especie',
#  131: 'Especie',
#  132: 'Especie',
#  133: 'Especie',
#  134: 'Especie',
#  135: 'Especie',
#  136: 'Especie',
#  137: 'Especie',
#  138: 'Especie',
#  139: 'Especie',
#  140: 'Especie',
#  141: 'Especie',
#  142: 'Genero',
#  143: 'Genero',
#  144: 'Genero',
#  145: 'Genero',
#  146: 'Genero',
#  147: 'Genero',
#  148: 'Genero',
#  149: 'Especie',
#  150: 'Especie',
#  151: 'Especie',
#  152: 'Especie',
#  153: 'Especie',
#  154: 'Especie',
#  155: 'Genero',
#  156: 'Genero',
#  157: 'Especie',
#  158: 'Especie',
#  159: 'Especie',
#  160: 'Genero',
#  161: 'Especie',
#  162: 'Especie',
#  163: 'Especie',
#  164: 'Especie',
#  165: 'Especie',
#  166: 'Especie',
#  167: 'Especie',
#  168: 'Especie',
#  169: 'Especie',
#  170: 'Especie',
#  171: 'Genero',
#  172: 'Especie',
#  173: 'Genero',
#  174: 'Genero',
#  175: 'Genero',
#  176: '',
#  177: 'Genero',
#  178: 'Genero',
#  179: 'Genero',
#  180: 'Genero',
#  181: 'Genero',
#  182: 'Especie',
#  183: 'Especie',
#  184: 'Especie',
#  185: 'Genero',
#  186: 'Genero',
#  187: 'Genero',
#  188: 'Especie',
#  189: 'Especie',
#  190: 'Especie',
#  191: 'Especie',
#  192: 'Genero',
#  193: 'Genero',
#  194: 'Especie',
#  195: 'Genero',
#  196: 'Especie',
#  197: 'Especie',
#  198: 'Especie',
#  199: 'Especie',
#  200: 'Especie',
#  201: 'Especie',
#  202: 'Especie',
#  203: '',
#  204: 'Genero',
#  205: 'Especie',
#  206: 'Especie',
#  207: 'Especie',
#  208: 'Especie',
#  209: 'Especie',
#  210: 'Especie',
#  211: 'Especie',
#  212: 'Genero',
#  213: 'Especie',
#  214: 'Especie',
#  215: 'Especie',
#  216: 'Especie',
#  217: 'Especie',
#  218: 'Especie',
#  219: 'Especie',
#  220: 'Especie',
#  221: 'Especie',
#  222: 'Familia',
#  223: 'Genero',
#  224: 'Especie',
#  225: 'Familia',
#  226: 'Familia',
#  227: '',
#  228: 'Familia',
#  229: 'Genero',
#  230: 'Especie',
#  231: 'Especie',
#  232: 'Especie',
#  233: 'Genero',
#  234: 'Especie',
#  235: 'Especie',
#  236: 'Genero',
#  237: 'Especie',
#  238: 'Especie',
#  239: 'Especie',
#  240: 'Especie',
#  241: 'Especie',
#  242: 'Genero',
#  243: 'Especie',
#  244: 'Especie',
#  245: 'Especie',
#  246: 'Especie',
#  247: 'Especie',
#  248: 'Especie',
#  249: 'Genero',
#  250: '',
#  251: 'Genero',
#  252: 'Especie',
#  253: 'Especie',
#  254: 'Especie',
#  255: 'Especie',
#  256: 'Especie',
#  257: 'Especie',
#  258: 'Especie',
#  259: 'Especie',
#  260: 'Especie',
#  261: 'Genero',
#  262: 'Especie',
#  263: 'Especie',
#  264: 'Genero',
#  265: 'Especie',
#  266: 'Especie',
#  267: 'Genero',
#  268: 'Especie',
#  269: 'Especie',
#  270: 'Especie',
#  271: 'Especie',
#  272: 'Genero',
#  273: 'Especie',
#  274: 'Especie',
#  275: 'Especie',
#  276: 'Especie',
#  277: '',
#  278: 'Especie',
#  279: 'Especie',
#  280: 'Especie',
#  281: 'Especie',
#  282: 'Especie',
#  283: 'Genero',
#  284: 'Genero',
#  285: 'Genero',
#  286: 'Genero',
#  287: 'Genero',
#  288: 'Genero',
#  289: 'Genero',
#  290: 'Genero',
#  291: 'Genero',
#  292: 'Genero',
#  293: 'Genero',
#  294: 'Familia',
#  295: 'Genero',
#  296: 'Genero',
#  297: 'Genero',
#  298: 'Familia',
#  299: 'Especie',
#  300: 'Familia',
#  301: 'Familia',
#  302: 'Familia',
#  303: 'Familia',
#  304: 'Familia',
#  305: 'Familia',
#  306: 'Familia',
#  307: 'Especie',
#  308: 'Especie',
#  309: 'Genero',
#  310: 'Especie',
#  311: 'Familia',
#  312: 'Especie',
#  313: 'Especie',
#  314: 'Especie',
#  315: 'Especie',
#  316: 'Especie',
#  317: 'Especie',
#  318: 'Especie',
#  319: 'Especie',
#  320: 'Especie',
#  321: 'Especie',
#  322: 'Especie',
#  323: 'Especie',
#  324: 'Especie',
#  325: 'Especie',
#  326: 'Especie',
#  327: 'Especie',
#  328: 'Familia',
#  329: 'Especie',
#  330: 'Familia',
#  331: 'Genero',
#  332: 'Genero',
#  333: 'Especie',
#  334: 'Familia',
#  335: 'Familia',
#  336: 'Familia',
#  337: 'Familia',
#  338: 'Familia',
#  339: 'Familia',
#  340: 'Familia',
#  341: 'Familia',
#  342: 'Familia',
#  343: 'Familia',
#  344: 'Especie',
#  345: 'Especie',
#  346: 'Especie',
#  347: 'Especie',
#  348: 'Familia',
#  349: 'Especie',
#  350: 'Familia',
#  351: 'Familia',
#  352: 'Especie',
#  353: 'Familia',
#  354: 'Especie',
#  355: 'Especie',
#  356: 'Especie',
#  357: 'Especie',
#  358: 'Familia',
#  359: 'Familia',
#  360: 'Genero',
#  361: 'Genero',
#  362: 'Familia',
#  363: 'Familia',
#  364: 'Familia',
#  365: 'Familia',
#  366: 'Familia',
#  367: 'Genero',
#  368: 'Especie',
#  369: 'Especie',
#  370: 'Especie',
#  371: 'Genero',
#  372: 'Familia',
#  373: 'Familia',
#  374: 'Familia',
#  375: 'Familia',
#  376: 'Especie',
#  377: 'Especie',
#  378: 'Familia',
#  379: 'Genero',
#  380: 'Genero',
#  381: 'Familia',
#  382: 'Familia',
#  383: 'Especie',
#  384: 'Genero',
#  385: 'Especie',
#  386: 'Especie',
#  387: 'Genero',
#  388: 'Familia',
#  389: 'Familia',
#  390: 'Especie',
#  391: 'Especie',
#  392: 'Especie',
#  393: 'Especie',
#  394: 'Genero',
#  395: 'Especie',
#  396: 'Especie',
#  397: 'Especie',
#  398: 'Especie',
#  399: 'Especie',
#  400: 'Especie',
#  401: 'Especie',
#  402: 'Genero',
#  403: 'Especie',
#  404: 'Familia',
#  405: 'Familia',
#  406: 'Genero',
#  407: 'Especie',
#  408: 'Especie',
#  409: 'Especie',
#  410: 'Genero',
#  411: 'Genero',
#  412: 'Genero',
#  413: 'Genero',
#  414: 'Genero',
#  415: 'Especie',
#  416: 'Especie',
#  417: 'Especie',
#  418: 'Especie',
#  419: 'Especie',
#  420: 'Familia',
#  421: 'Familia',
#  422: 'Familia',
#  423: 'Genero',
#  424: 'Especie',
#  425: 'Genero',
#  426: 'Especie',
#  427: 'Genero',
#  428: 'Genero',
#  429: 'Genero',
#  430: 'Genero',
#  431: 'Genero',
#  432: 'Especie',
#  433: 'Genero',
#  434: 'Especie',
#  435: 'Genero',
#  436: 'Genero',
#  437: 'Genero',
#  438: 'Genero',
#  439: 'Genero',
#  440: 'Genero',
#  441: 'Genero',
#  442: 'Especie',
#  443: 'Especie',
#  444: 'Especie',
#  445: 'Genero',
#  446: 'Especie',
#  447: 'Genero',
#  448: 'Especie',
#  449: 'Especie',
#  450: 'Especie',
#  451: 'Especie',
#  452: 'Especie',
#  453: 'Genero',
#  454: 'Especie',
#  455: 'Especie',
#  456: 'Genero',
#  457: 'Especie',
#  458: '',
#  459: 'Especie',
#  460: 'Genero',
#  461: 'Genero',
#  462: 'Especie',
#  463: 'Genero',
#  464: 'Especie',
#  465: 'Especie',
#  466: 'Especie',
#  467: 'Familia',
#  468: 'Familia',
#  469: 'Especie',
#  470: 'Familia',
#  471: 'Genero',
#  472: 'Especie',
#  473: 'Genero',
#  474: 'Especie',
#  475: 'Especie',
#  476: 'Especie',
#  477: 'Especie',
#  478: 'Especie',
#  479: 'Genero',
#  480: 'Genero',
#  481: 'Genero',
#  482: 'Genero',
#  483: 'Genero',
#  484: 'Especie',
#  485: 'Especie',
#  486: 'Especie',
#  487: 'Especie',
#  488: 'Especie',
#  489: 'Especie',
#  490: 'Especie',
#  491: 'Genero',
#  492: 'Familia',
#  493: 'Genero',
#  494: 'Especie',
#  495: 'Genero',
#  496: 'Especie',
#  497: 'Especie',
#  498: 'Especie',
#  499: 'Especie',
#  500: 'Especie',
#  501: 'Genero',
#  502: 'Especie',
#  503: 'Especie',
#  504: 'Genero',
#  505: 'Genero',
#  506: 'Especie',
#  507: 'Genero',
#  508: 'Genero',
#  509: 'Genero',
#  510: 'Genero',
#  511: 'Especie',
#  512: 'Especie',
#  513: 'Especie',
#  514: 'Especie',
#  515: 'Especie',
#  516: 'Genero',
#  517: 'Genero',
#  518: 'Especie',
#  519: 'Especie',
#  520: 'Especie',
#  521: 'Especie',
#  522: 'Especie',
#  523: 'Familia',
#  524: 'Familia',
#  525: 'Familia',
#  526: 'Familia',
#  527: 'Especie',
#  528: 'Familia',
#  529: 'Familia',
#  530: 'Familia',
#  531: 'Familia',
#  532: 'Especie',
#  533: 'Especie',
#  534: 'Especie',
#  535: 'Genero',
#  536: 'Genero',
#  537: 'Especie',
#  538: 'Especie',
#  539: 'Genero',
#  540: 'Genero',
#  541: 'Especie',
#  542: 'Familia',
#  543: 'Especie',
#  544: 'Especie',
#  545: 'Especie',
#  546: 'Especie',
#  547: 'Especie',
#  548: 'Especie',
#  549: 'Especie',
#  550: 'Especie',
#  551: 'Especie',
#  552: 'Especie',
#  553: 'Especie',
#  554: 'Especie',
#  555: 'Especie',
#  556: 'Especie',
#  557: 'Especie',
#  558: 'Especie',
#  559: 'Especie',
#  560: 'Especie',
#  561: 'Familia',
#  562: 'Familia',
#  563: 'Familia',
#  564: 'Especie',
#  565: 'Especie',
#  566: 'Especie',
#  567: 'Especie',
#  568: 'Especie',
#  569: 'Especie',
#  570: 'Especie',
#  571: 'Especie',
#  572: 'Especie',
#  573: 'Familia',
#  574: 'Familia',
#  575: 'Familia',
#  576: 'Familia',
#  577: 'Genero',
#  578: 'Genero',
#  579: 'Especie',
#  580: 'Genero',
#  581: 'Especie',
#  582: 'Genero',
#  583: 'Genero',
#  584: 'Especie',
#  585: 'Familia',
#  586: 'Genero',
#  587: 'Especie',
#  588: 'Genero',
#  589: 'Especie',
#  590: 'Especie',
#  591: 'Genero',
#  592: 'Especie',
#  593: 'Especie',
#  594: 'Genero',
#  595: 'Especie',
#  596: 'Especie',
#  597: 'Genero',
#  598: 'Especie',
#  599: 'Especie',
#  600: 'Genero',
#  601: 'Especie',
#  602: 'Especie',
#  603: 'Especie',
#  604: 'Especie',
#  605: 'Familia',
#  606: 'Familia',
#  607: 'Familia',
#  608: 'Genero',
#  609: 'Especie',
#  610: 'Especie',
#  611: '',
#  612: 'Genero',
#  613: 'Genero',
#  614: 'Genero',
#  615: 'Genero',
#  616: 'Genero',
#  617: 'Especie',
#  618: 'Familia',
#  619: 'Especie',
#  620: 'Especie',
#  621: 'Especie',
#  622: 'Especie',
#  623: 'Familia',
#  624: 'Genero',
#  625: 'Genero',
#  626: 'Especie',
#  627: 'Familia',
#  628: 'Genero',
#  629: 'Familia',
#  630: 'Genero',
#  631: 'Especie',
#  632: 'Familia',
#  633: 'Especie',
#  634: 'Especie',
#  635: 'Especie',
#  636: 'Especie',
#  637: 'Genero',
#  638: 'Genero',
#  639: 'Especie',
#  640: 'Genero',
#  641: 'Genero',
#  642: 'Genero',
#  643: 'Especie',
#  644: 'Especie',
#  645: 'Genero',
#  646: 'Familia',
#  647: 'Familia',
#  648: 'Especie',
#  649: 'Especie',
#  650: 'Especie',
#  651: 'Especie',
#  652: 'Genero',
#  653: 'Especie',
#  654: 'Especie',
#  655: 'Especie',
#  656: 'Genero',
#  657: 'Especie',
#  658: 'Especie',
#  659: 'Especie',
#  660: 'Especie',
#  661: 'Especie',
#  662: 'Especie',
#  663: 'Especie',
#  664: 'Especie',
#  665: 'Especie',
#  666: 'Genero',
#  667: 'Especie',
#  668: 'Especie',
#  669: 'Especie',
#  670: 'Especie',
#  671: 'Especie',
#  672: 'Especie',
#  673: 'Especie',
#  674: 'Especie',
#  675: 'Especie',
#  676: 'Especie',
#  677: 'Especie',
#  678: 'Especie',
#  679: 'Especie',
#  680: 'Especie',
#  681: 'Especie',
#  682: 'Especie',
#  683: 'Genero',
#  684: 'Especie',
#  685: 'Especie',
#  686: 'Genero',
#  687: 'Especie',
#  688: 'Genero',
#  689: 'Especie',
#  690: 'Genero',
#  691: 'Especie',
#  692: 'Especie',
#  693: 'Genero',
#  694: 'Genero',
#  695: 'Especie',
#  696: 'Genero',
#  697: 'Genero',
#  698: 'Genero',
#  699: 'Especie',
#  700: 'Genero',
#  701: 'Genero',
#  702: 'Genero',
#  703: 'Genero',
#  704: 'Especie',
#  705: 'Genero',
#  706: 'Genero',
#  707: 'Especie',
#  708: 'Genero',
#  709: 'Genero',
#  710: 'Genero',
#  711: 'Genero',
#  712: 'Genero',
#  713: 'Genero',
#  714: 'Genero',
#  715: 'Genero',
#  716: 'Especie',
#  717: 'Especie',
#  718: 'Especie',
#  719: 'Especie',
#  720: 'Especie',
#  721: 'Especie',
#  722: 'Familia',
#  723: 'Familia',
#  724: 'Familia',
#  725: 'Especie',
#  726: 'Genero',
#  727: 'Especie',
#  728: 'Especie',
#  729: 'Especie',
#  730: 'Especie',
#  731: 'Especie',
#  732: 'Familia',
#  733: 'Genero',
#  734: 'Especie',
#  735: 'Especie',
#  736: 'Especie',
#  737: 'Familia',
#  738: 'Familia',
#  739: 'Genero',
#  740: 'Genero',
#  741: 'Especie',
#  742: 'Familia',
#  743: 'Especie',
#  744: 'Especie',
#  745: 'Familia',
#  746: 'Genero',
#  747: 'Especie',
#  748: 'Especie',
#  749: 'Especie',
#  750: 'Especie',
#  751: 'Especie',
#  752: 'Especie',
#  753: 'Especie',
#  754: 'Especie',
#  755: 'Especie',
#  756: 'Especie',
#  757: 'Familia',
#  758: 'Especie',
#  759: 'Especie',
#  760: 'Familia',
#  761: 'Especie',
#  762: 'Genero',
#  763: 'Genero',
#  764: 'Genero',
#  765: 'Genero',
#  766: 'Especie',
#  767: 'Genero',
#  768: 'Especie',
#  769: 'Genero',
#  770: 'Familia',
#  771: 'Especie',
#  772: 'Especie',
#  773: 'Familia',
#  774: 'Familia',
#  775: 'Especie',
#  776: 'Especie',
#  777: 'Genero',
#  778: 'Especie',
#  779: 'Especie',
#  780: 'Genero',
#  781: 'Especie',
#  782: 'Especie',
#  783: 'Familia',
#  784: 'Especie',
#  785: 'Especie',
#  786: 'Especie',
#  787: 'Especie',
#  788: 'Especie',
#  789: 'Especie',
#  790: 'Especie',
#  791: 'Especie',
#  792: 'Genero',
#  793: 'Especie',
#  794: 'Especie',
#  795: 'Especie',
#  796: 'Especie',
#  797: 'Especie',
#  798: 'Genero',
#  799: 'Genero',
#  800: 'Genero',
#  801: 'Familia',
#  802: 'Especie',
#  803: 'Especie',
#  804: 'Especie',
#  805: 'Especie',
#  806: 'Especie',
#  807: 'Especie',
#  808: 'Especie',
#  809: 'Familia',
#  810: 'Genero',
#  811: '',
#  812: 'Genero',
#  813: 'Genero',
#  814: 'Genero',
#  815: 'Genero',
#  816: 'Genero',
#  817: 'Especie',
#  818: 'Familia',
#  819: 'Genero',
#  820: 'Genero',
#  821: 'Genero',
#  822: 'Genero',
#  823: 'Familia',
#  824: 'Genero',
#  825: 'Genero',
#  826: 'Genero',
#  827: 'Genero',
#  828: 'Especie',
#  829: 'Genero',
#  830: 'Genero',
#  831: 'Genero',
#  832: 'Familia',
#  833: '',
#  834: 'Familia',
#  835: 'Genero',
#  836: 'Familia',
#  837: 'Genero',
#  838: 'Genero',
#  839: 'Genero',
#  840: 'Genero',
#  841: 'Familia',
#  842: 'Familia',
#  843: 'Familia',
#  844: 'Familia',
#  845: 'Familia',
#  846: 'Familia',
#  847: 'Familia',
#  848: 'Familia',
#  849: 'Especie',
#  850: 'Genero',
#  851: 'Especie',
#  852: 'Especie',
#  853: 'Genero',
#  854: '',
#  855: '',
#  856: 'Especie',
#  857: 'Especie',
#  858: 'Especie',
#  859: 'Genero',
#  860: 'Genero',
#  861: 'Genero',
#  862: 'Especie',
#  863: 'Especie',
#  864: 'Especie',
#  865: 'Genero',
#  866: 'Especie',
#  867: 'Especie',
#  868: 'Especie',
#  869: 'Familia',
#  870: 'Genero',
#  871: 'Genero',
#  872: 'Especie',
#  873: 'Especie',
#  874: 'Especie',
#  875: 'Genero',
#  876: 'Especie',
#  877: 'Familia',
#  878: 'Especie',
#  879: 'Especie',
#  880: 'Especie',
#  881: 'Especie',
#  882: '',
#  883: '',
#  884: '',
#  885: 'Especie',
#  886: 'Especie',
#  887: 'Familia',
#  888: 'Familia',
#  889: 'Especie',
#  890: 'Familia',
#  891: 'Especie',
#  892: 'Especie',
#  893: 'Especie',
#  894: 'Especie',
#  895: 'Especie',
#  896: 'Especie',
#  897: 'Especie',
#  898: 'Especie',
#  899: 'Genero',
#  900: 'Especie',
#  901: 'Especie',
#  902: 'Especie',
#  903: 'Especie',
#  904: 'Especie',
#  905: 'Especie',
#  906: 'Especie',
#  907: 'Especie',
#  908: 'Especie',
#  909: 'Especie',
#  910: 'Especie',
#  911: 'Especie',
#  912: 'Especie',
#  913: 'Especie',
#  914: 'Especie',
#  915: 'Especie',
#  916: 'Genero',
#  917: 'Genero',
#  918: 'Especie',
#  919: 'Especie',
#  920: 'Especie',
#  921: 'Especie',
#  922: 'Genero',
#  923: 'Especie',
#  924: 'Genero',
#  925: 'Especie',
#  926: 'Especie',
#  927: 'Especie',
#  928: 'Especie',
#  929: 'Genero',
#  930: 'Especie',
#  931: 'Especie',
#  932: 'Genero',
#  933: 'Especie',
#  934: 'Genero',
#  935: 'Especie',
#  936: 'Especie',
#  937: 'Especie',
#  938: 'Especie',
#  939: 'Especie',
#  940: 'Especie',
#  941: 'Especie',
#  942: 'Especie',
#  943: 'Especie',
#  944: 'Especie',
#  945: 'Especie',
#  946: 'Especie',
#  947: 'Especie',
#  948: 'Especie',
#  949: 'Especie',
#  950: 'Especie',
#  951: 'Especie',
#  952: 'Especie',
#  953: 'Genero',
#  954: 'Genero',
#  955: 'Genero',
#  956: 'Genero',
#  957: 'Genero',
#  958: 'Genero',
#  959: 'Genero',
#  960: 'Genero',
#  961: 'Genero',
#  962: 'Genero',
#  963: 'Genero',
#  964: 'Genero',
#  965: 'Genero',
#  966: 'Genero',
#  967: 'Genero',
#  968: 'Genero',
#  969: 'Genero',
#  970: 'Genero',
#  971: 'Genero',
#  972: 'Genero',
#  973: 'Genero',
#  974: 'Genero',
#  975: 'Genero',
#  976: 'Genero',
#  977: 'Genero',
#  978: 'Genero',
#  979: 'Genero',
#  980: 'Genero',
#  981: 'Genero',
#  982: 'Genero',
#  983: 'Genero',
#  984: 'Genero',
#  985: 'Genero',
#  986: 'Genero',
#  987: 'Genero',
#  988: 'Genero',
#  989: 'Genero',
#  990: 'Genero',
#  991: 'Genero',
#  992: 'Genero',
#  993: 'Genero',
#  994: 'Genero',
#  995: 'Genero',
#  996: 'Genero',
#  997: 'Genero',
#  998: 'Genero',
#  999: 'Genero',
#  ...}

# %% [markdown]
# ## Filtragem do dataframe

# %%
print("Gera um novo dataframe com a filtragem desejada.")
my_filter = preparador.filter()
# Out:
# Gera um novo dataframe com a filtragem desejada.
# Filtrar dados por:
# 1. Estado
# 2. Nome de espécie
# 3. Categoria de ameaça
# Digite o número da opção: 1
# Digite a sigla do estado: PE
# Ocorrências com o filtro aplicado: 1360
#      Nome da instituicao Sigla da instituicao  \
# 0        Sem Informações               ICMBio
# 1        Sem Informações               ICMBio
# 2        Sem Informações               ICMBio
# 3        Sem Informações               ICMBio
# 4        Sem Informações               ICMBio
# ...                  ...                  ...
# 3865     Sem Informações               ICMBio
# 3866     Sem Informações               ICMBio
# 3867     Sem Informações               ICMBio
# 3910     Sem Informações               ICMBio
# 3911     Sem Informações               ICMBio
#
#                                   Nome da base de dados  \
# 0                 Atlas de Registro de Aves Brasileiras
# 1                 Atlas de Registro de Aves Brasileiras
# 2                 Atlas de Registro de Aves Brasileiras
# 3                 Atlas de Registro de Aves Brasileiras
# 4                 Atlas de Registro de Aves Brasileiras
# ...                                                 ...
# 3865  Sistema de Autorização e Informação em Biodive...
# 3866  Sistema de Autorização e Informação em Biodive...
# 3867  Sistema de Autorização e Informação em Biodive...
# 3910  Sistema de Autorização e Informação em Biodive...
# 3911  Sistema de Autorização e Informação em Biodive...
#
#                             Sigla da base de dados  \
# 0     ARA - Atlas de Registros de Aves Brasileiras
# 1     ARA - Atlas de Registros de Aves Brasileiras
# 2     ARA - Atlas de Registros de Aves Brasileiras
# 3     ARA - Atlas de Registros de Aves Brasileiras
# 4     ARA - Atlas de Registros de Aves Brasileiras
# ...                                            ...
# 3865                                  SISBIO-DIBIO
# 3866                                  SISBIO-DIBIO
# 3867                                  SISBIO-DIBIO
# 3910                                  SISBIO-DIBIO
# 3911                                  SISBIO-DIBIO
#
#                               Responsavel pelo registro  \
# 0     Ibama (Instituto Brasileiro de Meio Ambiente e...
# 1     Ibama (Instituto Brasileiro de Meio Ambiente e...
# 2     Ibama (Instituto Brasileiro de Meio Ambiente e...
# 3     Ibama (Instituto Brasileiro de Meio Ambiente e...
# 4     Ibama (Instituto Brasileiro de Meio Ambiente e...
# ...                                                 ...
# 3865                   Roberto Cavalcanti Barbosa Filho
# 3866                   Roberto Cavalcanti Barbosa Filho
# 3867                   Roberto Cavalcanti Barbosa Filho
# 3910                                        Maíra Pombo
# 3911                                        Maíra Pombo
#
#      Numero do registro no portal  \
# 0                   ARA-LIT-95641
# 1                   ARA-LIT-95642
# 2                   ARA-LIT-95643
# 3                   ARA-LIT-95644
# 4                   ARA-LIT-95645
# ...                           ...
# 3865                       998044
# 3866                       998045
# 3867                       998046
# 3910                       975640
# 3911                       975642
#
#                     Numero do registro na base de dados Data do registro  \
# 0                                       Sem Informações  Sem Informações
# 1                                       Sem Informações  Sem Informações
# 2                                       Sem Informações  Sem Informações
# 3                                       Sem Informações  Sem Informações
# 4                                       Sem Informações  Sem Informações
# ...                                                 ...              ...
# 3865  Nº Da Autorização/Licença Sisbio: 15277, Proje...       21/04/2008
# 3866  Nº Da Autorização/Licença Sisbio: 15277, Proje...       21/04/2008
# 3867  Nº Da Autorização/Licença Sisbio: 15277, Proje...       21/04/2008
# 3910  Nº Da Autorização/Licença Sisbio: 50823, Proje...       31/03/2016
# 3911  Nº Da Autorização/Licença Sisbio: 50823, Proje...       31/03/2016
#
#                Data do evento Data de Carencia  ...  \
# 0             Sem Informações       27/09/2017  ...
# 1             Sem Informações       27/09/2017  ...
# 2             Sem Informações       27/09/2017  ...
# 3             Sem Informações       27/09/2017  ...
# 4             Sem Informações       27/09/2017  ...
# ...                       ...              ...  ...
# 3865  22/04/2008 a 30/04/2008       17/01/2018  ...
# 3866  22/04/2008 a 30/04/2008       17/01/2018  ...
# 3867  22/04/2008 a 30/04/2008       17/01/2018  ...
# 3910  01/04/2016 a 05/04/2016       02/11/2017  ...
# 3911  01/04/2016 a 05/04/2016       02/11/2017  ...
#
#                                              Localidade             Pais  \
# 0                            APA de Fernando de Noronha  Sem Informações
# 1                            APA de Fernando de Noronha  Sem Informações
# 2                            APA de Fernando de Noronha  Sem Informações
# 3                            APA de Fernando de Noronha  Sem Informações
# 4                            APA de Fernando de Noronha  Sem Informações
# ...                                                 ...              ...
# 3865  Área De Proteção Ambiental De Fernando De Noro...           Brasil
# 3866     Parque Nacional Marinho De Fernando De Noronha           Brasil
# 3867     Parque Nacional Marinho De Fernando De Noronha           Brasil
# 3910     Parque Nacional Marinho De Fernando De Noronha           Brasil
# 3911     Parque Nacional Marinho De Fernando De Noronha           Brasil
#
#      Estado/Provincia            Municipio Status de Sensibilidade  Latitude  \
# 0                  PE  Fernando de Noronha    Espécie não Sensível -3.849000
# 1                  PE  Fernando de Noronha    Espécie não Sensível -3.849000
# 2                  PE  Fernando de Noronha    Espécie não Sensível -3.849000
# 3                  PE  Fernando de Noronha    Espécie não Sensível -3.849000
# 4                  PE  Fernando de Noronha    Espécie não Sensível -3.849000
# ...               ...                  ...                     ...       ...
# 3865               PE      Sem Informações    Espécie não Sensível -3.850000
# 3866               PE      Sem Informações    Espécie não Sensível -3.850000
# 3867               PE      Sem Informações    Espécie não Sensível -3.850000
# 3910               PE      Sem Informações    Espécie não Sensível -3.865667
# 3911               PE      Sem Informações    Espécie não Sensível -3.844944
#
#       Longitude            Outras informacoes da localidade       Jurisdicao  \
# 0    -32.420000              Coordenada exata da ocorr?ncia  Sem Informações
# 1    -32.420000              Coordenada exata da ocorr?ncia  Sem Informações
# 2    -32.420000              Coordenada exata da ocorr?ncia  Sem Informações
# 3    -32.420000              Coordenada exata da ocorr?ncia  Sem Informações
# 4    -32.420000              Coordenada exata da ocorr?ncia  Sem Informações
# ...         ...                                         ...              ...
# 3865 -32.416667  Coordenada de referência da área amostrada  Sem Informações
# 3866 -32.416667  Coordenada de referência da área amostrada  Sem Informações
# 3867 -32.416667  Coordenada de referência da área amostrada  Sem Informações
# 3910 -32.422917                       Coordenada aproximada  Sem Informações
# 3911 -32.428167                       Coordenada aproximada  Sem Informações
#
#             Destino do Material
# 0               Sem Informações
# 1               Sem Informações
# 2               Sem Informações
# 3               Sem Informações
# 4               Sem Informações
# ...                         ...
# 3865  Solto/mantido na natureza
# 3866  Solto/mantido na natureza
# 3867  Solto/mantido na natureza
# 3910    Destinado a laboratório
# 3911    Destinado a laboratório
#
# [1360 rows x 34 columns]

# %% [markdown]
# ## Plot da localização das espécies

# %%
# O plot é de todas as ocorrências do filtro acima
mapa = preparador.plot_map(my_filter)
display(mapa)
# Out:
# Map(basemap={'url': 'https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png', 'max_zoom': 19, 'attribution': 'Map …
